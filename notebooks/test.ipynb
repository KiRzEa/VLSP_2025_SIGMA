# %%
# %cd ..
# Out:
# d:\VLSP_2025_SIGMA

# %%
from src.core.config import settings
from src.services.llm_service.fpt_chat_model import FPTChatModel

# %%
chatbot = FPTChatModel(settings, model_name="Llama-4-Scout-17B-16E")

# %%
chatbot.generate(
    system_prompt="Useful assistant", 
    user_prompt="Bạn hãy dùng tri thức về biển báo để cho tôi biết ý nghĩa, nếu không biết chính xác hãy trả lời tôi không chắc chắn",
    image_paths=[
        "./sample/image160.jpg"
    ] 
)
# Out:
# '### **Ý nghĩa của biển báo DP.127c**  \r\nBiển báo **DP.127c** là một biển báo giao thông đặc biệt tại Việt Nam, được sử dụng để chỉ dẫn tốc độ tối đa cho các loại phương tiện trên đường. Biển này có thể áp dụng cho cả đường cao tốc hoặc những đoạn đường có giới hạn tốc độ khác nhau cho từng loại xe.\r\n\r\n### **Phân tích chi tiết:**  \r\n- **Cột bên trái (tốc độ 60 km/h):**  \r\n  - Dành cho ô tô và các phương tiện tương tự như xe SUV, xe tải nhỏ di chuyển trong điều kiện an toàn.  \r\n  - Tốc độ tối đa **60 km/h**, phù hợp với các đoạn đường đô thị hoặc khu vực đông dân cư.  \r\n\r\n- **Cột giữa (tốc độ 50 km/h):**  \r\n  - Dành cho ô tô con và xe tải nhẹ, với tốc độ tối đa **50 km/h**.  \r\n  - Có thể áp dụng cho các đoạn đường có lưu lượng giao thông cao hoặc yêu cầu kiểm soát tốc độ nghiêm ngặt hơn.  \r\n\r\n- **Cột bên phải (tốc độ 50 km/h) kèm hình ảnh các phương tiện:**  \r\n  - Dành cho xe máy, xe đạp điện, xe ba bánh, và xe đạp.  \r\n  - Tốc độ tối đa **50 km/h**, thường 
# ...
